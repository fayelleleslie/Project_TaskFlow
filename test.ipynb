# %% [markdown]
# ## Technologies Used
# - React - frontend framework
# - Node.js - runtime
# - MongoDB - database
# - CSS3 - styling
# - Express - backend framework

# %% [markdown]
# ## Installation
# 1. Clone the repository
# 2. Open the project folder
# 3. Run :
# npm install
# npm start
