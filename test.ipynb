# %% [markdown]
# ## Technologies Used
# - React - frontend framework
# - Node.js - runtime
# - MongoDB - database
# - CSS3 - styling
# - Express - backend framework

# %% [markdown]
# ## Installation
# 1. Clone the repository
# 2. Open the project folder
# 3. Run :
# npm install
# npm start

# %% [markdown]
# # My Calculator Project​
# ​
# This is a simple calculator application that I built using JavaScript.​
# ​
# ## Features
# - Basic operations (add, subtract, multiply, divide)​
# - Memory functions​
# - History of calculations​
# - Keyboard support​
# ​
# ## Technologies Used
# - HTML5​
# - CSS3​
# - JavaScript​
# - Local Storage​
# ​
# ## Installation Instructions
# - Clone the repository​
# - Open index.html in your browser​
# - Start calculating​
# ​
#
# You can reach me at: contact@example.com

# %% [markdown]
# | Technology | Purpose | Difficulty |
# |------------|---------|------------|
# | HTML | Structure | Easy |
# | CSS | Styling | Easy |
# | JavaScript | Interactivity | Medium |

# %% [markdown]
# # My Portfolio
#
# ## About Me
# **Naomie** - *sportive*
#
# ## Skills
# - Agility
# - Strength
# - Speed
# - Sociability
#
# ## Contact
# [my email] (naomie@gmail.com)
# ---
